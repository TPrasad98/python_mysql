# %%
#driver to establish the communication between jupyter notebook and mysql

# pip install mysql-connector-python

# !pip install mysql-connector-python

# %%
##importing mysql conector 
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost',user='root',passwd='Kanha@8144')

# %%
mydb

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('practicedb',),
#  ('students',),
#  ('students1',),
#  ('sys',)]

# %%
cursor.execute('create database if not exists practicedb')

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('create table if not exists practicedb.ineuron(studentId INT(10), firstName VARCHAR(30), lastname VARCHAR(30), regid INT(10), classname VARCHAR(50))')

# %%
cursor.execute('use  practicedb')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
cursor.execute("insert into practicedb.ineuron values(1,'satsis','roy',26262,'FSDS')")

# %%
mydb.commit()

# %%
cursor.execute('select * from practicedb.ineuron')

# %%
cursor.fetchall()
# Out:
# [(1, 'prasad', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'day', 26262, 'FSDS'),
#  (1, 'kumar', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS')]

# %%
ls
# Out:
# glass.data       sql-1_&_2.ipynb

# %%
pwd
# Out:
# '/Users/tariniprasaddas/data_science/MY_SQL'

# %%
file=open('glass.data','r')

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
import csv
with open('glass.data','r') as f:
    glass_data=csv.reader(f,delimiter='\n')
    for i in glass_data:
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
cursor.execute("create table if not exists practicedb.glassdata(col1 INT(10) , col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 INT(10)) ")

# %%
cursor.execute('use practicedb')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
cursor.execute("insert into practicedb.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)")

# %%
mydb.commit()

# %%
cursor.execute('select * from practicedb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
import csv
with open('glass.data','r') as f:
    glass_data=csv.reader(f,delimiter='\n')
    for i in glass_data:
        print(type(i[0]))
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute('insert into practicedb.glassdata values({values})'.format(values = ((i[0]))))
# Out:
# <class 'str'>
# insert into glassdata values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# <class 'str'>
# insert into glassdata values (7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1)
# <class 'str'>
# ...

# %%
mydb.commit()

# %%
cursor.execute('select * from practicedb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
import pandas as pd

# %%
pd.read_sql('select * from practicedb.glassdata',mydb)
# Out:
# /var/folders/rs/w1cppzrd0tg10lz07q7q90qm0000gn/T/ipykernel_860/3443418196.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('select * from practicedb.glassdata',mydb)
#       col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00   0.00      1
# 1        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00   0.00      1
# 2        6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00   0.26      1
# 3        7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00   0.00      1
# 4        8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00   0.00      1
# ...    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 1060   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06   0.00      7
# ...

# %%
pd.read_sql('show databases',mydb)
# Out:
# /var/folders/rs/w1cppzrd0tg10lz07q7q90qm0000gn/T/ipykernel_860/99043659.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('show databases',mydb)
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3          practicedb
# 4            students
# 5           students1
# 6                 sys

# %%
cursor.execute('select col1,col5,col10 from practicedb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(3, 1.54, 0.0),
#  (5, 1.24, 0.0),
#  (6, 1.62, 0.26),
#  (7, 1.14, 0.0),
#  (8, 1.05, 0.0),
#  (9, 1.37, 0.0),
#  (10, 1.36, 0.11),
#  (11, 1.56, 0.24),
#  (12, 1.27, 0.0),
#  (13, 1.4, 0.24),
#  (14, 1.27, 0.17),
#  (15, 1.31, 0.0),
#  (16, 1.23, 0.0),
#  (17, 1.16, 0.0),
#  (18, 0.89, 0.0),
#  (19, 1.18, 0.0),
#  (20, 1.69, 0.07),
#  (21, 1.49, 0.19),
#  (22, 0.29, 0.0),
#  (23, 1.29, 0.0),
#  (24, 1.35, 0.0),
#  (25, 1.15, 0.0),
#  (26, 1.21, 0.0),
#  (27, 1.41, 0.0),
#  (28, 1.33, 0.0),
#  (29, 1.43, 0.0),
#  (30, 1.28, 0.0),
#  (31, 1.3, 0.14),
#  (32, 1.14, 0.0),
#  (33, 1.23, 0.22),
#  (34, 1.38, 0.06),
#  (35, 1.34, 0.0),
#  (36, 1.21, 0.0),
#  (37, 1.32, 0.0),
#  (38, 1.35, 0.0),
#  (39, 0.47, 0.0),
#  (40, 0.47, 0.0),
#  (41, 1.12, 0.0),
#  (42, 1.2, 0.0),
#  (43, 1.33, 0.0),
#  (44, 0.72, 0.0),
#  (45, 1.19, 0.3),
#  (46, 1.35, 0.0),
#  (47, 1.18, 0.16),
#  (48, 0.71, 0.1),
#  (49, 0.79, 0.0),
#  (50, 1.23, 0.0),
#  (51, 0.51, 0.16),
#  (52, 1.28, 0.11),
# ...

# %%
cursor.execute("select * from practicedb.glassdata WHERE col1=1 AND col11=1")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
cursor.execute("delete from practicedb.glassdata WHERE col1=2")

# %%
mydb.commit()

# %%
cursor.execute("select * from practicedb.glassdata WHERE col1=2")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("UPDATE practicedb.glassdata SET col1=6 AND col2 = 8 WHERE col1=3")

# %%
mydb.commit()

# %%
cursor.execute("select * from practicedb.glassdata")

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('select col1, col2 from practicedb.glassdata WHERE col1=1')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101), (1, 1.52101), (1, 1.52101), (1, 1.52101), (1, 1.52101)]

# %%
cursor.execute("select * from practicedb.glassdata")

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
import pandas as pd

# %%
pd.read_sql("select * from practicedb.glassdata",mydb)
# Out:
# /var/folders/rs/w1cppzrd0tg10lz07q7q90qm0000gn/T/ipykernel_860/1762104107.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from practicedb.glassdata",mydb)
#       col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0        0  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00   0.00      1
# 1        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00   0.00      1
# 2        6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00   0.26      1
# 3        7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.00   0.00      1
# 4        8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.00   0.00      1
# ...    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 1058   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06   0.00      7
# ...

# %%
cursor.execute("select * from practicedb.ineuron")

# %%
cursor.fetchall()
# Out:
# [(1, 'prasad', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'day', 26262, 'FSDS'),
#  (1, 'kumar', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS')]

# %%
pd.read_sql("select * from practicedb.ineuron",mydb)
# Out:
# /var/folders/rs/w1cppzrd0tg10lz07q7q90qm0000gn/T/ipykernel_860/3381249442.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from practicedb.ineuron",mydb)
#    studentId firstName lastname  regid classname
# 0          1    prasad      das  26262      FSDS
# 1          1     kumar      das  26262      FSDS
# 2          1     kumar      day  26262      FSDS
# 3          1     kumar      roy  26262      FSDS
# 4          1    satsis      roy  26262      FSDS
# 5          1    satsis      roy  26262      FSDS
# 6          1    satsis      roy  26262      FSDS
# 7          1    satsis      roy  26262      FSDS

# %%
cursor.execute("select col1 , col2 , col6 from practicedb.glassdata")

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 72.99),
#  (5, 1.51742, 73.08),
#  (6, 1.51596, 72.97),
#  (7, 1.51743, 73.09),
#  (8, 1.51756, 73.24),
#  (9, 1.51918, 72.08),
#  (10, 1.51755, 72.99),
#  (11, 1.51571, 73.2),
#  (12, 1.51763, 73.01),
#  (13, 1.51589, 73.28),
#  (14, 1.51748, 73.21),
#  (15, 1.51763, 73.29),
#  (16, 1.51761, 73.24),
#  (17, 1.51784, 73.11),
#  (18, 1.52196, 71.36),
#  (19, 1.51911, 72.12),
#  (20, 1.51735, 72.73),
#  (21, 1.5175, 72.75),
#  (22, 1.51966, 72.02),
#  (23, 1.51736, 72.79),
#  (24, 1.51751, 73.02),
#  (25, 1.5172, 72.85),
#  (26, 1.51764, 73.0),
#  (27, 1.51793, 72.64),
#  (28, 1.51721, 73.04),
#  (29, 1.51768, 73.15),
#  (30, 1.51784, 72.86),
#  (31, 1.51768, 73.08),
#  (32, 1.51747, 73.27),
#  (33, 1.51775, 72.97),
#  (34, 1.51753, 73.39),
#  (35, 1.51783, 72.95),
#  (36, 1.51567, 72.74),
#  (37, 1.51909, 71.81),
#  (38, 1.51797, 72.96),
#  (39, 1.52213, 71.77),
#  (40, 1.52213, 71.77),
#  (41, 1.51793, 73.03),
#  (42, 1.51755, 73.2),
#  (43, 1.51779, 72.76),
# ...

# %%
cursor.execute("select col1 , col2 , col6 from practicedb.glassdata WHERE col1=1")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 71.78),
#  (1, 1.52101, 71.78),
#  (1, 1.52101, 71.78),
#  (1, 1.52101, 71.78),
#  (1, 1.52101, 71.78)]

# %%
cursor.execute("select col1, count(col1) from practicedb.glassdata group by col1  ")

# %%
cursor.fetchall()
# Out:
# [(0, 8),
#  (5, 5),
#  (6, 5),
#  (7, 5),
#  (8, 5),
#  (9, 5),
#  (10, 5),
#  (11, 5),
#  (12, 5),
#  (13, 5),
#  (14, 5),
#  (15, 5),
#  (16, 5),
#  (17, 5),
#  (18, 5),
#  (19, 5),
#  (20, 5),
#  (21, 5),
#  (22, 5),
#  (23, 5),
#  (24, 5),
#  (25, 5),
#  (26, 5),
#  (27, 5),
#  (28, 5),
#  (29, 5),
#  (30, 5),
#  (31, 5),
#  (32, 5),
#  (33, 5),
#  (34, 5),
#  (35, 5),
#  (36, 5),
#  (37, 5),
#  (38, 5),
#  (39, 5),
#  (40, 5),
#  (41, 5),
#  (42, 5),
#  (43, 5),
#  (44, 5),
#  (45, 5),
#  (46, 5),
#  (47, 5),
#  (48, 5),
#  (49, 5),
#  (50, 5),
#  (51, 5),
#  (52, 5),
#  (53, 5),
#  (54, 5),
#  (55, 5),
#  (56, 5),
#  (57, 5),
#  (58, 5),
#  (59, 5),
#  (60, 5),
#  (61, 5),
#  (62, 5),
#  (63, 5),
#  (64, 5),
#  (65, 5),
#  (66, 5),
#  (67, 5),
#  (68, 5),
#  (69, 5),
#  (70, 5),
#  (71, 5),
#  (72, 5),
#  (73, 5),
#  (74, 5),
#  (75, 5),
#  (76, 5),
#  (77, 5),
#  (78, 5),
#  (79, 5),
#  (80, 5),
#  (81, 5),
#  (82, 5),
#  (83, 5),
#  (84, 5),
#  (85, 5),
#  (86, 5),
# ...

# %%
cursor.execute("select * from practicedb.glassdata where col1=0  ")

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (0, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (0, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (0, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1)]

# %%
cursor.execute("select * from practicedb.ineuron ")

# %%
cursor.fetchall()
# Out:
# [(1, 'prasad', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'day', 26262, 'FSDS'),
#  (1, 'kumar', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS')]

# %%
cursor.execute("select * from practicedb.ineuron  ")

# %%
cursor.fetchall()
# Out:
# [(1, 'prasad', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'das', 26262, 'FSDS'),
#  (1, 'kumar', 'day', 26262, 'FSDS'),
#  (1, 'kumar', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS'),
#  (1, 'satsis', 'roy', 26262, 'FSDS')]

# %%
cursor.execute("select count(*),regid from practicedb.ineuron group by regid ")

# %%
cursor.fetchall()
# Out:
# [(8, 26262)]

# %%
cursor.execute(" select count(*) , classname from practicedb.ineuron where classname='FSDS' ")

# %%
cursor.fetchall()
# Out:
# [(8, 'FSDS')]

# %%
cursor.execute("select firstName from practicedb.ineuron where regid=26262 ")

# %%
cursor.fetchall()
# Out:
# [('prasad',),
#  ('kumar',),
#  ('kumar',),
#  ('kumar',),
#  ('satsis',),
#  ('satsis',),
#  ('satsis',),
#  ('satsis',)]

# %%
## order by ascending order
cursor.execute("select * from practicedb.glassdata  order by col2")

# %%
cursor.fetchall()
# Out:
# [(185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
# ...

# %%
## order by descending order 
cursor.execute("select * from practicedb.glassdata  order by col2 desc ")
cursor.fetchall()
# Out:
# [(108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select * from (select * from practicedb.glassdata  where col1 > 112) as sudh  where col11 = 3")

# %%
cursor.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cursor.execute("select * from practicedb.glassdata    ")

# %%
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select *  from practicedb.glassdata where col1 = 11 or col11 = 2")

# %%
cursor.fetchall()
# Out:
# [(11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (72, 1.51848, 13.64, 3.87, 1.27, 71.96, 0.54, 8.32, 0.0, 0.32, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (74, 1.51631, 13.34, 3.57, 1.57, 72.87, 0.61, 7.89, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2),
#  (78, 1.51627, 13.0, 3.58, 1.54, 72.83, 0.61, 8.04, 0.0, 0.0, 2),
#  (79, 1.51613, 13.92, 3.52, 1.25, 72.88, 0.37, 7.94, 0.0, 0.14, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (83, 1.51646, 13.41, 3.55, 1.25, 72.81, 0.68, 8.1, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select *  from practicedb.glassdata where col1 = 77 and col11 = 2")
cursor.fetchall()
# Out:
# [(77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2),
#  (77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2),
#  (77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2),
#  (77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2),
#  (77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2)]

# %%
cursor.execute("select * from practicedb.glassdata where  col2 like '1.515%'")
cursor.fetchall()
# Out:
# [(6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (84, 1.51594, 13.09, 3.52, 1.55, 72.87, 0.68, 8.05, 0.0, 0.09, 2),
#  (87, 1.51569, 13.24, 3.49, 1.47, 73.25, 0.38, 8.03, 0.0, 0.0, 2),
#  (93, 1.51588, 13.12, 3.41, 1.58, 73.26, 0.07, 8.39, 0.0, 0.19, 2),
# ...

# %%
cursor.execute("select * from practicedb.glassdata where  col2 like '%.51%'")
cursor.fetchall()
# Out:
# [(0, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from practicedb.glassdata where col1>112  and col3 like '%%.2%%' ")
cursor.fetchall()
# Out:
# [(117, 1.51829, 13.24, 3.9, 1.41, 72.33, 0.55, 8.31, 0.0, 0.1, 2),
#  (121, 1.51844, 13.25, 3.76, 1.32, 72.4, 0.58, 8.42, 0.0, 0.0, 2),
#  (123, 1.51687, 13.23, 3.54, 1.48, 72.84, 0.56, 8.1, 0.0, 0.0, 2),
#  (125, 1.52177, 13.2, 3.68, 1.15, 72.75, 0.54, 8.52, 0.0, 0.0, 2),
#  (142, 1.51851, 13.2, 3.63, 1.07, 72.83, 0.57, 8.41, 0.09, 0.17, 2),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (170, 1.51994, 13.27, 0.0, 1.76, 73.03, 0.47, 11.32, 0.0, 0.0, 5),
#  (193, 1.51623, 14.2, 0.0, 2.79, 73.46, 0.04, 9.04, 0.4, 0.09, 7),
#  (214, 1.51711, 14.23, 0.0, 2.08, 73.36, 0.0, 8.62, 1.67, 0.0, 7),
#  (117, 1.51829, 13.24, 3.9, 1.41, 72.33, 0.55, 8.31, 0.0, 0.1, 2),
#  (121, 1.51844, 13.25, 3.76, 1.32, 72.4, 0.58, 8.42, 0.0, 0.0, 2),
#  (123, 1.51687, 13.23, 3.54, 1.48, 72.84, 0.56, 8.1, 0.0, 0.0, 2),
#  (125, 1.52177, 13.2, 3.68, 1.15, 72.75, 0.54, 8.52, 0.0, 0.0, 2),
#  (142, 1.51851, 13.2, 3.63, 1.07, 72.83, 0.57, 8.41, 0.09, 0.17, 2),
# ...

# %%
##two level of queries or sub queries
cursor.execute("select * from (select * from practicedb.glassdata where col1>112) as kanha  where col11= 3  and col3 like '%%.2%%' ")
cursor.fetchall()
# Out:
# [(149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3)]

# %%
cursor.execute("select * from practicedb.glassdata group by col1 having count(col1)>6 ")
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 cursor.execute("select * from practicedb.glassdata group by col1 having count(col1)>6 ")
#       2 cursor.fetchall()
#
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:303, in CMySQLCursor.execute(self, operation, params, multi)
#     301 except (ProgrammingError, ReferenceError) as err:
#     302     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 303 self._cnx.handle_unread_result()
#     305 stmt = ""
#     306 self.reset()
#
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/connection_cext.py:961, in CMySQLConnection.handle_unread_result(self, prepared)
#     959     self.consume_results()
#     960 elif unread_result:
# --> 961     raise InternalError("Unread result found")
#
# InternalError: Unread result found
